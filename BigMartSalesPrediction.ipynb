# %%
import pandas as pd

# %%
df = pd.read_csv("bigmart.csv")

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
x = df['Item_Weight'].mean()
x
# Out:
# 12.857645184136183

# %%
df['Item_Weight']=df['Item_Weight'].fillna(13)

# %%
x = df['Outlet_Size'].mode()
x
# Out:
# 0    Medium
# dtype: object

# %%
df['Outlet_Size']=df['Outlet_Size'].fillna('Medium')

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace(['low fat','LF'],'Low Fat')

# %%
df.head(30)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10       13.000          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
df = df.replace(['reg'],'Regular')

# %%
del df['Item_Identifier']
del df['Outlet_Identifier']

# %%
df.head(30)
# Out:
#     Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.300          Low Fat         0.016047                  Dairy
# 1         5.920          Regular         0.019278            Soft Drinks
# 2        17.500          Low Fat         0.016760                   Meat
# 3        19.200          Regular         0.000000  Fruits and Vegetables
# 4         8.930          Low Fat         0.000000              Household
# 5        10.395          Regular         0.000000           Baking Goods
# 6        13.650          Regular         0.012741            Snack Foods
# 7        13.000          Low Fat         0.127470            Snack Foods
# 8        16.200          Regular         0.016687           Frozen Foods
# 9        19.200          Regular         0.094450           Frozen Foods
# 10       11.800          Low Fat         0.000000  Fruits and Vegetables
# 11       18.500          Regular         0.045464                  Dairy
# ...

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.010875  0.024643
# Item_Visibility              -0.010875         1.000000 -0.001315
# Item_MRP                      0.024643        -0.001315  1.000000
# Outlet_Establishment_Year    -0.017163        -0.074834  0.005020
# Item_Outlet_Sales             0.012574        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.017163           0.012574
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(df, corner=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Item_Weight'])
# Out:
# (array([ 483.,  870.,  865.,  664.,  779., 2092.,  755.,  735.,  677.,
#          603.]),
#  array([ 4.555 ,  6.2345,  7.914 ,  9.5935, 11.273 , 12.9525, 14.632 ,
#         16.3115, 17.991 , 19.6705, 21.35  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Item_Visibility'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d29e5f13a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d29e4d80d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d29e5f17f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d29e4d8430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d29e4a3eb0>],
#  'means': []}

# %%
plt.scatter(df.Item_Outlet_Sales, df.Item_Type)
plt.title("Item_Outlet_Sales versus Item_Type")
plt.xlabel("Item_Outlet_Sales")
plt.ylabel("Item_Type")
# Out:
# Text(0, 0.5, 'Item_Type')

# %%
plt.violinplot(df['Item_Weight'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2d2a02caf10>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2d2a02cae80>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2d2a02dd490>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2d2a02dd7c0>}

# %%
plt.scatter(df.Item_Fat_Content, df.Item_Visibility)
plt.title("Item_Fat_Content versus Item_Visibility")
plt.xlabel("Item_Fat_Content")
plt.ylabel("Item_Visibility")
# Out:
# Text(0, 0.5, 'Item_Visibility')

# %%
plt.boxplot(df['Item_MRP'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d2a0740730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d2a0740e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d2a0740370>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d2a074a5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d2a074a940>],
#  'means': []}

# %% [markdown]
# # Model Building

# %%
import statsmodels.formula.api as smf

# %%
df.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998      Medium               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# ...

# %%
model_df = smf.ols('Item_Outlet_Sales~Item_Weight+Item_Fat_Content+Item_Visibility+Item_Type+Item_MRP+Outlet_Establishment_Year+Outlet_Size+Outlet_Location_Type+Outlet_Type', data=df).fit()

# %%
model_df.params
# Out:
# Intercept                            -81240.705927
# Item_Fat_Content[T.Regular]              40.315614
# Item_Type[T.Breads]                       6.867722
# Item_Type[T.Breakfast]                    9.166938
# Item_Type[T.Canned]                      26.826463
# Item_Type[T.Dairy]                      -39.906368
# Item_Type[T.Frozen Foods]               -28.330087
# Item_Type[T.Fruits and Vegetables]       31.205799
# Item_Type[T.Hard Drinks]                  2.481055
# Item_Type[T.Health and Hygiene]         -11.000664
# Item_Type[T.Household]                  -38.532794
# Item_Type[T.Meat]                         0.938110
# Item_Type[T.Others]                     -22.334558
# Item_Type[T.Seafood]                    188.183443
# Item_Type[T.Snack Foods]                 -9.272010
# Item_Type[T.Soft Drinks]                -27.176618
# Item_Type[T.Starchy Foods]               23.457859
# Outlet_Size[T.Medium]                  -932.563752
# ...

# %%
model_df.rsquared
# Out:
# 0.5634674092368711

# %%
print(model_df.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      Item_Outlet_Sales   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     406.1
# Date:                Mon, 20 Jun 2022   Prob (F-statistic):               0.00
# Time:                        23:34:18   Log-Likelihood:                -71991.
# No. Observations:                8523   AIC:                         1.440e+05
# Df Residuals:                    8495   BIC:                         1.442e+05
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
#Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
var = df.select_dtypes(include='object').columns

# %%
var
# Out:
# Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
for i in var:
    df[i] = le.fit_transform(df[i])

# %%
df.head(2)
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 0         0.016047          4  249.8092
# 1         5.92                 1         0.019278         14   48.2692
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            1                     0            1
# 1                       2009            1                     2            2
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228

# %%
x = df.drop(['Item_Outlet_Sales'], axis=1)
y = df['Item_Outlet_Sales']

# %%
x.head(2)
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 0         0.016047          4  249.8092
# 1         5.92                 1         0.019278         14   48.2692
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                       1999            1                     0            1
# 1                       2009            1                     2            2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
df.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 0         0.016047          4  249.8092
# 1         5.92                 1         0.019278         14   48.2692
# 2        17.50                 0         0.016760         10  141.6180
# 3        19.20                 1         0.000000          6  182.0950
# 4         8.93                 0         0.000000          9   53.8614
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            1                     0            1
# 1                       2009            1                     2            2
# 2                       1999            1                     0            1
# 3                       1998            1                     2            0
# 4                       1987            0                     2            1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# ...

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred[:5]
# Out:
# array([2331.54534927, 2510.82999567, 1987.08399714, 2223.55914293,
#        2808.21145262])

# %%
y_test[:5]
# Out:
# 4931    1426.1436
# 4148    1201.7690
# 7423    1836.2764
# 4836    2410.8618
# 944     1549.9824
# Name: Item_Outlet_Sales, dtype: float64

# %%
print("Train Accuracy: ", model.score(x_train, y_train))
print("Test Accuracy: ", model.score(x_test, y_test))
# Out:
# Train Accuracy:  0.5099099502442802
# Test Accuracy:  0.49685338758280095

# %%
from sklearn import tree

# %%
from sklearn.ensemble import RandomForestRegressor
x_train = df.drop(['Item_Outlet Sales', 'Item Identifier', 'Outlet_Identifier'],axis=1)
y_train = df['Item_Outlet Sales'] 
x_test = ds.drop(['Item_Identifier', 'Outlet Identifier'],axis=1).copy()
rf = RandomForestRegressor(n_estimators-400,max_depth-6, min_samples_leaf=100,n_jobs=4)
rf.fit(x_train,y_train)
rf_pred = rf.predict(x_test)
rf_accuracy = round(rf.score (x_train,y_train)*100,2) 
print('accuracy of random forest is : %.4g' %rf_accuracy)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7536/2970486986.py in <module>
#       1 from sklearn.ensemble import RandomForestRegressor
# ----> 2 x_train = df.drop(['Item_Outlet Sales', 'Item Identifier', 'Outlet_Identifier'],axis=1)
#       3 y_train = df['Item_Outlet Sales']
#       4 x_test = ds.drop(['Item_Identifier', 'Outlet Identifier'],axis=1).copy()
#       5 rf = RandomForestRegressor(n_estimators-400,max_depth-6, min_samples_leaf=100,n_jobs=4)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...
